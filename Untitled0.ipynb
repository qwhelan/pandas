# %%
import pandas as pd
import numpy as np

# %%
n = 100
df = pd.DataFrame(np.random.randn(n, 5), index=pd.DatetimeIndex(start='1/1/2000', freq='B', periods=n))

# %%
# %lprun -f pd.tools.plotting.LinePlot._maybe_convert_index df.plot()
# Out:
# <class 'pandas.tseries.period.PeriodIndex'>
# [2000-01-03, ..., 2000-05-19]
# Length: 100, Freq: B
# <class 'pandas.tseries.period.PeriodIndex'>
# [2000-01-03, ..., 2000-05-19]
# Length: 100, Freq: B
# <class 'pandas.tseries.period.PeriodIndex'>
# [2000-01-03, ..., 2000-05-19]
# Length: 100, Freq: B
# <class 'pandas.tseries.period.PeriodIndex'>
# [2000-01-03, ..., 2000-05-19]
# Length: 100, Freq: B
# <class 'pandas.tseries.period.PeriodIndex'>
# [2000-01-03, ..., 2000-05-19]
# Length: 100, Freq: B

# %%
df.plot()
# Out:
# <class 'pandas.tseries.period.PeriodIndex'>
# [2000-01-03, ..., 2000-05-19]
# Length: 100, Freq: B
# <class 'pandas.tseries.period.PeriodIndex'>
# [2000-01-03, ..., 2000-05-19]
# Length: 100, Freq: B
# <class 'pandas.tseries.period.PeriodIndex'>
# [2000-01-03, ..., 2000-05-19]
# Length: 100, Freq: B
# <class 'pandas.tseries.period.PeriodIndex'>
# [2000-01-03, ..., 2000-05-19]
# Length: 100, Freq: B
# <class 'pandas.tseries.period.PeriodIndex'>
# [2000-01-03, ..., 2000-05-19]
# Length: 100, Freq: B
